# %% [markdown]
# -[x] TicTacToe
# -[x] __init_
# -[x] get_random_first_player
# -[x] fix_spot : marks a spot on the board
# -[x] is_player_win : checks if a player has won
# -[x] is_board_filled : checks if the board is full
# -[x] swap_player_turn : switches the turn between players
# -[x] show_board : displays the current state of the board

# %%
import random

class TicTacToe:
    def __init__(self):
        self.board = [' '] * 10    #list(map(str, range(10)))
        self.player_turn = 'X'
        
        
    def show_board(self):
        print('\n')
        print(self.board[7] + '|' + self.board[8] + '|' + self.board[9])
        print('-+-+-')
        print(self.board[4] + '|' + self.board[5] + '|' + self.board[6])
        print('-+-+-')
        print(self.board[1] + '|' + self.board[2] + '|' + self.board[3])
        print('\n')
        
    def swap_player_turn(self):
        self.player_turn = 'X' if self.player_turn == 'O' else 'O'
        return self.player_turn
    
    def is_board_filled(self):
        return ' ' not in self.board[1:]
    
    def fix_spot(self, cell, player):
        self.board[cell] = player
        
    def is_player_win(self, player):
        win_combinations = [
            [1, 2, 3], [4, 5, 6], [7, 8, 9],  # rows
            [1, 4, 7], [2, 5, 8], [3, 6, 9],  # columns
            [1, 5, 9], [3, 5, 7]              # diagonals
        ]
        for combination in win_combinations:
            if all(self.board[cell] == player for cell in combination):
                return True
            return False
        
    def get_random_first_player(self):
        return 'X' if random.randint(0, 1) == 0 else 'O'
    
    def start(self):
        while True:
            self.show_board()
            print(f"player {self.player_turn} turn")
            cell = int(input("Enter the cell number (1-9) to fix spot:"))
            
            if self.board[cell] == ' ' and cell in range(1,10):
                self.fix_spot(cell, self.player_turn)
                
                if self.is_player_win(self.player_turn):
                    self.show_board()
                    print(f"player {self.player_turn} wins the game!")
                    break
                if self.is_board_filled():
                    self.show_boared()
                    print("Match Draw!")
                    break
                else:
                    print("Invalid cell!! Try again")
                    continue
                self.swap_player_turn()
                print("Thanks for playing")

# %%
game = TicTacToe()
game.player_turn
game.show_board()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 game = TicTacToe()
#       2 game.player_turn
#       3 game.show_board()
#
# NameError: name 'TicTacToe' is not defined

# %%
game.show_board()
# Out:
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
